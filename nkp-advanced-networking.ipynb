# %%
from IPython.core.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from sys import path; path.insert(1,"../src");
import fubar; from importlib import reload; reload(fubar);
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-advanced-networking/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Advanced Networking``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %%
# from sys import path; path.insert(1,"../src")
# from fubar import fFile

# %%
# %%script bash
# grep -1 "def fFile" ../src/fubar.py -A 9
# Out:
# # repository ./SeanOhAileasa
# def fFile(nParPath):
#     """Start a file with its associated application.
#
# Input: nParPath
# Process: (os.path.realpath; os.startfile)
# Output: file opened with associated application
# """
#     from os import path,startfile
#     return startfile(path.realpath(nParPath))
# # --- END ---

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Advanced Networking](#topAdvancedNetworking)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topAdvancedNetworkingTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Advanced Networking](#advancedNetworking)
#
# * [1. Multilayer Switches](#advancedNetworking1MultilayerSwitches) <br/><br/>
# * [2. Wireless Controllers](#advancedNetworking2WirelessControllers) <br/><br/>
# * [3. Load Balancers](#advancedNetworking3LoadBalancers) <br/><br/>
# * [4. Intrusion Detection System (IDS) and Intrusion Prevention System (IPS)](#advancedNetworking4IDSandIPS) <br/><br/>
# * [5. Proxy Servers](#advancedNetworking5ProxyServers) <br/><br/>
# * [6. VPN Concentrators](#advancedNetworking6VPNConcentrators) <br/><br/>
# * [7. AAA Services](#advancedNetworking7AAAServices) <br/><br/>
# * [8. UTM Appliances](#advancedNetworking8UTMAppliances) <br/><br/>
# * [9. Next-generation Firewall (NGFW) & Layer 7 Firewalls](#advancedNetworking9NextgenerationFirewallNGFWLayer7Firewalls) <br/><br/>
# * [10. VoIP Gateways](#advancedNetworking10VoIPGateways) <br/><br/>
# * [11. Content Filters](#advancedNetworking11ContentFilters)

# %% [markdown]
# ### [Practice: Configuring Advanced Networking](#practiceAdvancedNetworkingConfiguringAdvancedNetworking)
#
# * [1. Exercise: Advanced Networking Configure Advanced Networking Devices](#exerciseAdvancedNetworkingConfigureAdvancedNetworkingDevices)

# %% [markdown]
# <a id="topAdvancedNetworkingTest"></a>
# ### ⚡ [Test](#advancedNetworkingTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking"></a>
# ***
# ### Advanced Networking
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking1MultilayerSwitches"></a>
# ***
# ###### 1. Multilayer Switches
# ***

# %% [markdown]
# In this presentation, we'll take a look at multilayer switches, which are network devices [Multilayer Switches.] that are capable of operating at both Layers 2 and 3 of the OSI model.

# %% [markdown]
# So we've discussed earlier how switches reside at Layer 2 and base their packet forwarding decisions on the MAC address.

# %% [markdown]
# Routers reside at Layer 3 and base their packet forwarding decisions on IP address.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Switching and Routing - Application Specific Integrated Circuit (ASIC)
# ***

# %% [markdown]
# Well, now we have a device that can, in fact, perform both basic functions, switching and routing. Now it uses what's known as an application specific integrated circuit, which is also referred to as an ASIC circuit, to accomplish the routing tasks.

# %% [markdown]
# So, again, it is just a 2-in-1 type of device. So in terms of the actual network configuration, we see here [In the diagram there are two networks: Network A and Network B. Each network has four systems that are interconnected with a switch and both the networks are connected with a Multilayer Switch. ] Network A and of course Network B, and you might have traditionally placed a router in between them, provided they were using separate network addresses. So, again, perhaps Network A was 192.168.0 and network B was 192.168.1. Those are separate network addresses.

# %% [markdown]
# Well, a multilayer switch can still route between them. It can examine the IP address and decide whether or not it should forward the packet. But it can also just act as a switch. So in terms of reconfiguring, you wouldn't have to do anything. But in fact, you could if you wanted to. You could make Network A, Segment A, and make it 192.168.0, and then maybe the first 5 addresses or 10 addresses or 50 addresses, it doesn't matter within that subnet.

# %% [markdown]
# But then network B could become just Segment B, and it could still be 192.168.0 as long as the address range did not overlap. So, again, if the first one went to, let's say 10, then the second one could start at 11. So as long as there were no conflicts, then you could make this entire configuration one network. But, again, I stress, you didn't have to, that was just an option. You could leave them exactly as they were, because a multilayer switch is able to assess the forwarding determination based on the IP address as well.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Autoconfigurable
# ***

# %% [markdown]
# [Multilayer Switches — Benefits.] So in terms of some of the benefits, it provides an ease of use with respect to the fact that it is autoconfigurable. Now switches pick up on the MAC address, that is attached to any physical port, automatically. In other words, they construct their MAC tables on their own. But routers don't do that. You have to program routers to say that this is the network on this side and this is the network on the other side. But because they are able to detect the addresses now at Layer 3, they can do, effectively, the same thing, and they can build tables based on the IP address. So there is an autoconfiguration with respect to both switching and routing. So there's no requirement to learn a new kind of IP switching technology, it configures itself.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Convergence
# ***

# %% [markdown]
# Convergence refers to the fact that it can respond to route failures and routing topology changes because it understands routing. It actually also understands routing protocols, the protocols that routers use to talk to each other to inform them about topology changes.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Resiliency - Hot Standby Router Protocol (HSRP)
# ***

# %% [markdown]
# This also enhances the resiliency. It supports the Hot Standby Router Protocol, or HSRP, which eliminates a single point of failure, meaning that any given device can transparently switch to a standby device without disrupting services.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Access Lists
# ***

# %% [markdown]
# They support access lists, so that you can filter the traffic based on the access list, accept packets from this interface but not from that interface. And you can use that to prevent traffic from crossing between subnets, if you want to. It can quite simply reject traffic destined for any given subnet based on the address.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Transparency
# ***

# %% [markdown]
# Transparency means that you don't have to implement any new routing protocols. And it supports DHCP as well, so that you don't have to reconfigure any of the end systems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Standards-based
# ***

# %% [markdown]
# And it is standards based. It uses the Internet Engineering Task Force standard protocols such as OSPF, or Open Shortest Path First, and Routing Information Protocol.

# %% [markdown]
# Again, the protocols that routers use to talk to each other to exchange their routing tables and their status.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits -  Simplify the overall Network Design
# ***

# %% [markdown]
# And it allows you to just simplify the overall network design because you can retain your existing subnet structure. As mentioned, you can change it if you want to, but you don't have to.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits - Supports Management - Account and Traffic
# ***

# %% [markdown]
# And finally, it supports management with respect to accounting and analyzing the traffic. So you can generate reports that effectively indicate what kind of traffic has been crossing from one to the other.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Perform either Function
# ***

# %% [markdown]
# So, again, just several benefits available from implementing a multilayer switch. But most of all, the fact that they can perform either function.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking2WirelessControllers"></a>
# ***
# ###### 2. Wireless Controllers
# ***

# %% [markdown]
# Now in this presentation, we'll take a look at a wireless controller which is a centralized Wi-Fi management device [Wireless Controller.] that allows you to manage all access points in a network.

# %% [markdown]
# The general idea being that, if you do have a lot of wireless devices, or wireless access points, rather than configuring each one individually, the wireless controller allows you to configure them all. And depending on the make or model, you might also be able to configure features such as VPN connectivity, intrusion detection and even the firewall settings.

# %% [markdown]
# So again, it's just simpler to connect to this centralized device and then have access to all of the devices rather than making multiple connections over and over again. And in a lot of cases, probably setting them fairly consistently with each other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Centralized Authentication
# ***

# %% [markdown]
# Now, it also offers centralized authentication. One of the ways by which you can implement authentication on your wireless access points is to create MAC address tables. So that this particular MAC address is allowed to connect, while these ones aren't.

# %% [markdown]
# So again, you would not have to create individual MAC address tables on each access point. You can do it all from the central location.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Centralized Authentication - Radius Server
# ***

# %% [markdown]
# Now, they can also perform authentication using what's known as Radius servers. Now, we'll talk about that in greater detail later on, but at a basic level, it is the ability to forward the authentication request off to a centralized mechanism. So, rather than the device itself authenticating you, it says hold on, let me pass that off to the central device, and it will authenticate you. And again, this allows you to configure a single authentication policy that is consistent across all devices rather than configuring multiple policies that are essentially the same.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Centralized Authentication - Active Directory - Lightweight Directory Access Protocol (LDAP)
# ***

# %% [markdown]
# It also supports Active Directory Authentication, as well as lightweight directory access protocol for environments that still use directory services but maybe just not the Windows Active Directory.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Interference Mitigation
# ***

# %% [markdown]
# It also offers interference mitigation whereby the access points will always operate in non-overlapping channels to reduce the interference as much as possible.

# %% [markdown]
# If you have a very densely populated wireless network environment then you can reduce the loss of packets due to this interference.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Load Balancing
# ***

# %% [markdown]
# And it also supports load balancing, which is the ability to shift users to adjacent access points if the load simply becomes unbalanced.

# %% [markdown]
# For example, if one access point has a very high volume of users while another access point is very low, then it can transparently shift them to the other device as long as they are within range, of course.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Radio Balancing
# ***

# %% [markdown]
# And radio balancing is similar but it's based on the 802.11 specification.

# %% [markdown]
# So what you see here is that all 802.11n clients, for example, would always connect to an 802.11n access point.

# %% [markdown]
# And we've seen earlier that some of them are compatible with each other. So it will always try its best to make sure that the As are with the A and the Bs are with the B, the Ns with the Ns and so on.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Failover
# ***

# %% [markdown]
# And finally failover is the ability to automatically shift to a neighboring access point during failure. So again, that if one does go down, the clients that were connected to it can be sent off to a different access point provided they are still within range but it does offer that better resiliency when dealing with those connections.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Lot of Access Points
# ***

# %% [markdown]
# So ultimately, if you do have a lot of access points, then it certainly makes sense to implement a centralized wireless controller.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking3LoadBalancers"></a>
# ***
# ###### 3. Load Balancers
# ***

# %% [markdown]
# Now in this presentation, we'll introduce the idea of load balancing. And in particular, we'll look at the hardware load-balancing device, or HLD. [Load Balancer.]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hardware Load-Balancing (HLD)
# ***

# %% [markdown]
# Now there are software mechanisms in place that can also load balance. But, for the time being, we'll talk about the hardware device.

# %% [markdown]
# This is a physical networking appliance that is used to distribute traffic across multiple servers as evenly as possible. Now a key component is that those servers all have to be performing the same task. Now they don't necessarily have to be dedicated to that task. But every server that is behind the load balancer must at least supply the same consistent service as every other system.

# %% [markdown]
# So a good example is a website. If I have a very busy website, then one server might not be able to handle the load. So I think to myself, well, I'll create a server farm and I'll have the site hosted on two servers, then either one can respond. That's the basic idea, but then you also want to ensure that server one is not handling, let's say, 90% of the load while server two is only handling 10. Now each of those servers could then also perform other tasks that don't necessarily need to be load balanced. And that's what I referred to when I said they have to at least have one consistent service. But, typically, that's what you are concerned with. Let's make sure that we can handle the load of the website traffic. But let's spread it across multiple servers. And, by no means, does it need to be only two servers.  You could have dozens upon dozens as long as they are all hosting that same website or performing the same service.

# %% [markdown]
# Now in terms of routing the traffic, it will try its best to distribute the traffic evenly. But evenly doesn't just come down to the numbers. So using a simple example, if it was only two servers then you might think well, let's split it up 50/50. But you also have to consider availability, resource utilization, the number of connections overall, and quite simply, the performance of that server.

# %% [markdown]
# So if, for example, server one is a very good, very robust server, while server two is not so good, well, then, in fact, you would want server one to handle more of the requests. So it will take into account all of these considerations. And particularly once you start dealing with, let's say, ten servers, then availability also comes into play. Because one of them might go down. Two of them might go down. In which case, the load balancer will ensure that it does not forward the requests to a server that has gone down.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefits
# ***

# %% [markdown]
# So in terms of benefits, it minimizes the probability that servers will become overwhelmed by the traffic. So, again, a slight exaggeration that I mentioned earlier, but if one server was handling 90% and another was only handling 10, well, you're certainly more likely to see server one become overwhelmed, it's doing too much.

# %% [markdown]
# It can also optimize the bandwidth to each computer or terminal. Again, it can take into account a number of considerations. So it can forward a request off to a server that is simply not utilizing the bandwidth as much as it should.

# %% [markdown]
# And it can minimize the network downtime. Because if you do have multiple servers, even just two, and one of them goes down, there is still another one to service the request. So you have less downtime, better resiliency.

# %% [markdown]
# Now you can also perform traffic prioritization and end-to-end application monitoring. Which involves, in essence, saying, if a request comes in for this type of service and that is deemed to be a little more important than a different type of service, then we can give that a little more priority. Because you don't have to balance just one type of service. You can balance any number of services. So that allows you to put more weight on the type of protocol or the type of request that is coming in. And that monitoring ability is to flat out determine which systems have been doing what. So we can ensure that the balance is there. That we aren't seeing overutilization and underutilization.

# %% [markdown]
# It can also provide user authentication with the load balancing mechanisms.

# %% [markdown]
# And you can protect against malicious activity such as a denial-of-service attack. Because clients that are in front of the load balancer, if you will, do not see behind it. So launching an attack against this service has to go through the load balancer. So it can be configured, of course, to reject those types of requests that don't seem to be legitimate.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Multiple Servers handling a Single Service
# ***

# %% [markdown]
# So, ultimately, if you do require this type of configuration where you want to have multiple servers handling a single service, then it typically makes sense to implement the load balancer to ensure the optimal performance of that service.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking4IDSandIPS"></a>
# ***
# ###### 4. Intrusion Detection System (IDS) and Intrusion Prevention System (IPS)
# ***

# %% [markdown]
# In this presentation, we'll take a look at network intrusion from two different perspectives, [Intrusion Detection System.] one of detection and one of prevention.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Intrusion Detection System (IDS)
# ***

# %% [markdown]
# So beginning with detection, the idea really is that key word, it detects suspicious activity on either an individual host or the entire network.

# %% [markdown]
# It is a system that's designed to analyze traffic patterns and to, effectively, try to determine what is normal, for lack of a better word. Then anything that occurs that is not normal, or out of the ordinary, might be considered to be an intrusion. But, in terms of mitigation, it can assist in mitigating that detected activity, but typically in the form of just logging it. Taking note of the fact that something did occur. [IDS.] So what it really comes down to is that the IDS is the solution that can detect suspicious activity, but it does not necessarily stop it. It is more so up to you to go through the logs and assess what did take place and then, perhaps, take some action based on what you are seeing. So it really is the key word of intrusion detection. Detecting something does not prevent it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Intrusion Prevention System (IPS)
# ***

# %% [markdown]
# [IPS.] So this is where we see the Intrusion Prevention System come into play. And this is a solution that can both detect the suspicious network activity, and furthermore, in many cases, prevent an attack.

# %% [markdown]
# So what you typically find is that the IDS will perform the detection, learn what is normal and what is abnormal. And then based on that information, you can then configure the IPS to flat out stop that type of traffic. You can effectively say that yes, this appears to be an intrusion. So if you see that same pattern again, stop it from happening.

# %% [markdown]
# So, typically, most of the devices can perform both tasks, but there needs to be a little bit of a learning curve, if you will.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Firewalls
# ***

# %% [markdown]
# [Network Firewalls.] Now, I also want to include the network firewall in this presentation because it's similar, but it's not really the same.

# %% [markdown]
# The firewall is simply configured to allow or deny network traffic based on packet header contents such as the IP address, a protocol type and/or a port number.

# %% [markdown]
# And it's placed, very much like an IDS/IPS, in between the Internet and your private network.

# %% [markdown]
# But the firewall doesn't really assess anything other than what you see here. And it doesn't really make any decisions based on previous historic patterns or anything along those lines. If the IP address appears to be correct, if the protocol type appears to be correct, and the port number appears to be correct, well, then the firewall will let that traffic through.

# %% [markdown]
# But, of course, a skilled attacker will be able to find their way around that, if you will. They disguise the packet so that they appear to be legitimate. They have the correct IP address, they have the correct protocol type, and the correct port number. It is simply the contents that, of course, are malicious. So it's never a bad idea to have both a firewall and an IDS/IPS for the highest levels of protection. But firewalls in and of themselves only examine those contents and, effectively, allow or deny the traffic accordingly.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementation - Intrusion Detection System (IDS)
# ***

# %% [markdown]
# [Intrusion Detection System.] So when it comes to the Intrusion Detection System, and in a moment, the Intrusion Prevention System, you do have two choices, very much like a firewall, in terms of the implementation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementation - Intrusion Detection System (IDS) - Host-based
# ***

# %% [markdown]
# You can have a host-based IDS. In other words, you can have it directly on a specific host, such as a web server or a database server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementation - Intrusion Detection System (IDS) - Network-based
# ***

# %% [markdown]
# Or you can have a network-based IDS. And in terms of placement here, it has to be able to see all network traffic to identify any suspect activity. It will then log that suspicious activity and it may alert you or notify of a threat but, again, generally doesn't stop it. It just says this occurred, pay attention to this.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementation - Intrusion Prevention System (IPS)
# ***

# %% [markdown]
# [Intrusion Prevention System.] And the same goes for the Intrusion Prevention System.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementation - Intrusion Prevention System (IPS) - Host-based
# ***

# %% [markdown]
# You can have the host-based IPS, which runs on an individual network host.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementation - Intrusion Prevention System (IPS) - Network-based
# ***

# %% [markdown]
# Or you can have a network-based IPS, whereby it also has to see all network traffic to identify and prevent the suspicious activity. So, typically, you want that placed as closed to the Internet as possible, for both the IPS and the IDS. And, of course, this also can log the suspicious activity so that you can still see it. You know, I want to know when this type of intrusion was attempted. I certainly want to prevent the threat in the first place, but I want to know about it as well. So maybe we can be even a little more proactive and take some additional measures to ensure that these intrusions do not find their way into your network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking5ProxyServers"></a>
# ***
# ###### 5. Proxy Servers
# ***

# %% [markdown]
# [Proxy Servers.] Are implemented to eliminate direct connectivity between your internal clients and Internet resources.

# %% [markdown]
# And in fact, in the opposite direction as well, Internet clients and internal resources. Now, that's actually what's known as a reverse proxy configuration.

# %% [markdown]
# But it protects the true host identity because all outgoing traffic appears to come from the proxy. And in fact, it's not just a matter of it appearing to come from the proxy, it does come from the proxy. So we see the internal clients using private IP addresses. They just simply want to go to a website, for example. The proxy server intervenes, if you will, and says hold on, I'll get that site for you. So it has a public IP address configured that faces the Internet. It is the proxy server that goes out and retrieves the site and then it sends it back to the client.

# %% [markdown]
# So again, you get this protection of the internal clients because it's only ever the proxy server that directly accesses the Internet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Configuration
# ***

# %% [markdown]
# Now, it has to be configured to proxy a specific application. So for example, if you are wanting to gain access to a website, it would have to proxy the HTTP protocol.

# %% [markdown]
# And if you also wanted it to proxy FTP requests, you certainly could. But you do have to tell it which application protocols are going to be proxied. Anything that is not listed, in essence, would bypass the proxy.

# %% [markdown]
# Now, transparent proxies do not really require any kind of client configuration. In other words, you don't have to do a whole lot on the client to configure it. You just really tell it to go through the proxy, that's about it. And a lot of browsers these days are capable of detecting a proxy as well. So from the client's perspective, it is all very transparent. You might not even know that you are going through a proxy server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefit - Cached Content
# ***

# %% [markdown]
# So again, the idea is that the proxy server is actually the system that retrieves the Internet content for the internal requesting client. But, another nice feature is that the content that does come back can be cached to speed up subsequent requests. In other words, if I request website X, then the server can cache some of that content. Now, these days we know a lot of websites are very dynamic. But some of it can still be cached. So that if you go and request the same site, a good portion of it can actually come back from the proxy itself. And it doesn't even have to go out to the Internet. So you get your site back at LAN speeds, not Internet speeds. So they can dramatically increase the performance as well. And again, the internal client identity is never revealed, so you get a lot of benefits from using proxy servers.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Benefit - Control or Restriction or Security
# ***

# %% [markdown]
# Now, another benefit is that you can implement a certain degree of control or restriction or even security. Because proxy servers can examine the packet headers and the payload. So for example, you can block connections to things like social networking sites outside of lunch hours. Or you can flat out block an entire site based on the domain name, for example.

# %% [markdown]
# So you can ensure that your people aren't wasting time during business hours. You can control which sites are accessible and which ones are blocked or restricted. And you can even implement these time controls, so that maybe it is allowed during certain hours.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Caching Servers - Time To Live (TTL)
# ***

# %% [markdown]
# Now, as mentioned earlier, proxy servers can cache the content. So as such, they're often referred to as caching servers. Now this depends on how the proxy server is configured because you don't have to enable caching. That is really up to you. But if you do enable it, then you might also want to consider cache aging timers, also known as the time to live, or TTL, value. In other words, how long is the cached content valid for? As mentioned, a lot of sites these days are very dynamic. They change all the time, especially weather or news sites. So in that event, if I go to the site and then it is cached. And then you go to the site later on, the decision is well, is that cached content still valid or has it changed? So if you feel that you are always accessing, or at least frequently accessing, very dynamic sites, then you should have a very short TTL. Because the original content is changing. But if you feel that you access fairly static sites more often, then you can increase the TTL and you'll get better performance. But once the TTL expires, the cached content is removed. So again, if it is very dynamic, cache it for maybe 15 minutes or something like that. Then it expires, then the next person to go to that site will have to go all the way to the originating site to get the current content.

# %% [markdown]
# So it's a little bit slower but it's more up to date. Cached is faster but might not be as current.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Prefetched Internet Content
# ***

# %% [markdown]
# Now there's also prefetched Internet content, which can be scheduled. This can speed up content access when requested by internal clients.

# %% [markdown]
# Now again, you have to consider the static versus dynamic nature of the cached content. So again, this is quite literally proxy servers realizing that these sites are very often accessed. Therefore, we can proactively request that content and cache it ahead of time.

# %% [markdown]
# Now again, this is something that is entirely up to you. You can enable this feature, disable it, configure it however you want. So it does depend, to a degree, on knowing what the normal behavior is within your environment and which sites are accessed most frequently. But you can, of course, examine that information and decide for yourself over time if these features are beneficial.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Reverse Proxy Servers
# ***

# %% [markdown]
# [Reverse Proxy Servers.] Now, the reverse proxy was touched on earlier. And this is effectively the opposite direction, the requesting client is on the Internet.

# %% [markdown]
# So they are trying to gain access to resources within your environment, for lack of a better word. And we see here the requesting client coming in through the reverse proxy to access a web server.

# %% [markdown]
# So if you think about the regular proxy representing the clients, then this is the exact opposite. The reverse proxy represents the servers.

# %% [markdown]
# Now, the idea is that you might have multiple web servers in a lot of cases. So if a request comes in for a particular site, the proxy server is also responsible for directing that client to the appropriate web server. So if I have even just two web servers, let's say I have Site A on Server A and Site B on Server B.

# %% [markdown]
# Then it's the job of the reverse proxy to forward me off to the correct web server. So it listens for these connections on the appropriate ports. And then those incoming connections are forwarded to the appropriate internal host. [For example, it listens for TCP port 80 web site connections.] So that's just the reverse nature of this type of request. It originates from the Internet, not from the internal environment.

# %% [markdown]
# Now these are normally placed in a demilitarized zone for publicly accessible services. This still protects the true identity of the internal host. But now the internal host is the server, not the client. And again, it's transparent to the external users. The use of a reverse proxy is not known to the clients. They have no idea that they aren't directly communicating with the web server. But that's the idea, I want all incoming requests to hit the reverse proxy. The reverse proxy will then decide to which server this request should be sent. And again, there can be any number of servers providing any number of services to the Internet clients. So this protects all of your servers that are behind the proxy and allows all traffic to be controlled through the proxy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Handles the Request - Either Client or Server
# ***

# %% [markdown]
# But one way or another, a proxy server is always responsible for handling the request on behalf of someone else. Either the requesting clients or the servers that service those requests.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking6VPNConcentrators"></a>
# ***
# ###### 6. VPN Concentrators
# ***

# %% [markdown]
# All right, in this presentation, we'll take a look at the VPN concentrator, [VPN Concentrator.] which is a networking device used to provide remote access for virtual private networks.

# %% [markdown]
# Now, just to touch on the VPN itself for a moment, this is implemented when you have disconnected workers. Those who work from home or those who travel and need to access the internal resources of your organization over the Internet.

# %% [markdown]
# So once a VPN is established, they can access those resources, such as the printers, the servers, the storage, just like they were in the actual internal office. So, typically, what you'll see is software on those computers for the disconnected users that they will launch. And they will provide the necessary connectivity information, such as the username and password and the server or address to which they want to connect. Then once they establish that connection, they might as well be in the office. They can work just like anyone else, but, of course, from the outside.

# %% [markdown]
# But the VPN concentrator is implemented to act as a dedicated device. Because most network servers have the ability to create and establish VPN connections. But then you have to take one of your servers and, basically, expose it to the Internet because the system to which the users want to connect needs to be accessible from the Internet.

# %% [markdown]
# So by using a VPN concentrator, you can keep all of your servers behind the concentrator and not directly exposed to the Internet.

# %% [markdown]
# Plus, as a dedicated device, the VPN concentrator allows typically higher throughput and other benefits, such as handling the encryption. Because, of course, we are using the public Internet as our means to communicate. So we want to ensure that the data is encrypted.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Implementation - Site-to-Site
# ***

# %% [markdown]
# Now, they're typically implemented in what's known as a site-to-site VPN architecture. And this is where you have two, or more, physical sites.

# %% [markdown]
# So let's imagine you have a larger office, we'll call it headquarters, and then maybe a branch office with fewer users. But the people in the branch office need fairly frequent access to the resources in headquarters. So, in that case, it doesn't really make sense for them to launch the software to establish the connection every time they need access, they might need access all day every day.

# %% [markdown]
# So a site-to-site maintains a much more persistent connection that all users can use, rather than individuals making multiple connections all of the time. That more casual type of connection, such as the travelling user who only needs access periodically while they are travelling, is known as a point-to-point. That's when they open the software, they enter in the information, they establish a connection, they go about their business and then they close it down once they are finished. So that, again, is much less frequent and for far fewer users. So, again, that is typically known as the point-to-point. So you'll generally see VPN concentrators used when it is that more robust site-to-site. But it doesn't have to be, that's just a common implementation.

# %% [markdown]
# But it can handle all of the tasks involved with establishing and maintaining the VPN, such as establishing the tunnel, the connection between the two, authenticating the users to ensure that only the appropriate people are gaining access.

# %% [markdown]
# It can assign the IP address to the users so that they get an address that is consistent with the rest of the internal environment. It can handle the encryption and decryption of data, and it can ensure the delivery of the data.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Encryption - ``IPsec`` - ``SSL``
# ***

# %% [markdown]
# So coming back to the encryption, as mentioned, when you establish a VPN, you are using the public Internet as your means. So we need to use it in a private fashion, hence, the term VPN.

# %% [markdown]
# So in terms of the encryption, this is typically implemented using Internet Protocol Security, or IPsec, or SSL, Secure Sockets Layer, and that's the same protocol that you'll see for secured websites.

# %% [markdown]
# Any address that is HTTPS is using SSL to implement the security. So, again, it's not that the network servers could not handle the encryption, but this offloads the necessity. So the VPN concentrator handles the encryption so that you don't have to worry about it with respect to the internal resources. Everything is encrypted from the client to the concentrator, but once it arrives at the concentrator, it will handle the decryption. And present the network servers or the printers, or the storage with already decrypted requests so that it does not have to handle the encryption/decryption as well as servicing the request of the client.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Authentication
# ***

# %% [markdown]
# And another significant component in establishing a VPN is authentication. You want to ensure that only valid users are gaining access. So authentication is always the process of identifying yourself, providing the credentials, the username and the password. So this can be achieved with a variety of protocols. But most VPN devices are able to integrate, or interoperate, with authentication services and/or protocols.

# %% [markdown]
# Such as Microsoft's Active Directory, the Kerberos protocol, which in fact is what Active Directory uses for authentication, but it's not dedicated to Active Directory. Digital certificates, and the Remote Authentication Dial In User Service, or RADIUS protocol.

# %% [markdown]
# Now we'll actually talk about that in an upcoming presentation, but for the most part, it is a centralized authentication service where you might have multiple access points. And rather than configuring, let's say, five different access points with the same authentication information, they will just pass the authentication request off to a different server. It will handle the authentication and pass that authentication back to the client. So it's just a more centralized implementation of authentication. But again, ideally, what you want is for the VPN concentrator to at least accept the request and then pass it off to the appropriate server or service.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - VPN Concentrator helps Decentralize and Manage Connections
# ***

# %% [markdown]
# So, generally, when you have a fair amount of users who will need fairly frequent access to your internal organization by using VPNs, then a VPN concentrator can help decentralize and manage all of those connections.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking7AAAServices"></a>
# ***
# ###### 7. AAA Services
# ***

# %% [markdown]
# Now in this presentation, we'll introduce the concept of AAA services, [AAA Services.] which are designed for remote access connections to provide authentication, authorization, and accounting, hence, the three A's.

# %% [markdown]
# So AAA does not refer to a single process or a single task, but it is, rather, a generalized statement that incorporates each of these tasks using a variety of protocols.

# %% [markdown]
# Now RADIUS, TACACS+, and Kerberos are simply examples of protocols that qualify, for lack of a better word, as AAA service protocols.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Authentication
# ***

# %% [markdown]
# But with respect to each of those processes, authentication is always the identify yourself component. Provide a username and a password, possibly something else to prove that you are who you claim to be. And Kerberos is just one example of an authentication protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Authorization
# ***

# %% [markdown]
# Authorization is, then, what are you allowed to do. You can make the connection but that does not mean you can access every resource in the internal environment, you are allowed to access this or perform this task, so that's the authorization component.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Accounting
# ***

# %% [markdown]
# And accounting is simply keeping track of it all, who connected, when did they connect, from where, how long did they remain connected and what did they do while they were connected?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocols
# ***

# %% [markdown]
# So how you choose to implement those particular tasks is up to you.

# %% [markdown]
# So again, RADIUS, TACACS+, and Kerberos are just examples of protocols that can handle some of these services for you. They are primarily concerned with authentication. So we'll take a look at each of them. But, in essence, this is just the general implementation for remote access connections and how you satisfy those requests.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocols - Remote Authentication Dial-In User Service (RADIUS)
# ***

# %% [markdown]
# [RADIUS.] So beginning with RADIUS, this is the Remote Authentication Dial-In User Service.

# %% [markdown]
# It's an 802.1x standard based AAA protocol for remote connections, but typically involves centralizing the authentication request.

# %% [markdown]
# If you have just a single network access server, then you can configure the authentication and the security on that server. And since it's the only one, it handles all connections. So you know that every one is going to be configured the same.

# %% [markdown]
# But in larger, more robust environments, you might have multiple network access servers. In which case, you might find yourself configuring the exact same security configuration and authentication configuration on each of those servers. So, in other words, the policy is the same on every one of those servers and as this grows, if you have 5 or 10 or 20, you end up configuring the exact same security policy across all of those servers.

# %% [markdown]
# RADIUS says, well, only implement a single security policy on the RADIUS server. Then when the requests come in from the network access servers, they will simply forward the request back to the RADIUS server. It will handle the authentication and then allow the user through.

# %% [markdown]
# So this way, you only configure a single policy as opposed to several policies which are effectively identical.

# %% [markdown]
# So this is very widely used for VPNs, various types of access points, and any other remote access type with respect to the security. It just allows you to simplify the process by implementing that single consistent policy and then every access point adheres to that same policy.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocols - Terminal Access Controller Access Control System (TACACS+)
# ***

# %% [markdown]
# [TACACS+.] Now TACACS+ is Terminal Access Controller Access Control System, this is a Cisco developed open standard for AAA services and is still primarily concerned with authentication.

# %% [markdown]
# But where RADIUS only encrypts the passwords and the usernames are sent in clear text, TACACS+ encrypts all information between the client and server. So it's a little more secure. But, again, it is a Cisco developed protocol so it's not only supported by Cisco devices, it is an open standard. But, typically, you will see it implemented when you do have Cisco hardware.

# %% [markdown]
# But, ultimately, it is a little more secure than RADIUS because of the fact that usernames are sent in clear text when implementing RADIUS.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Protocols
# ***

# %% [markdown]
# So, again, it's up to you, you can choose whichever method you feel is appropriate. There are, in some cases, some compatibility concerns, perhaps older devices might not support this particular protocol or this particular method. So there are always considerations.

# %% [markdown]
# Plus, a little bit of overhead is always involved with certain protocols. But, ultimately, these are just some examples of how you can implement the AAA services within your VPN environment.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking8UTMAppliances"></a>
# ***
# ###### 8. Unified Threat Management (UTM) Appliances
# ***

# %% [markdown]
# In this presentation, we'll take a look at Unified Threat Management or UTM. [UTM.]

# %% [markdown]
# This is an all-in-one security device that was designed to replace the typical firewall. Because a firewall, in and of itself, is only designed to protect the internal environment based on things like the protocol and the port and the IP address. That's not particularly comprehensive. There are several means by which you can establish a connection including routing and VPNs. But there are a number of different threats to those types of connections. Anti-virus, anti-spyware, email, and anti-spam, intrusion prevention systems, quality of service and bandwidth management, web security. All of those things have to be considered. And the UTM was designed to do exactly that.

# %% [markdown]
# To take into consideration all of the methods of connectivity, and to implement an appropriate type of security for each of those types of connections.

# %% [markdown]
# So it consolidates many security services into the one device. Whereas in the past, you would have purchased many devices or applications to handle each one of those specific threats.

# %% [markdown]
# The UTM secures your network by providing many standard services such as a firewall, intrusion detection and prevention, antivirus and anti-spyware, VPN connectivity and load balancing, and content filtering, such as on a proxy server to implement web security in many cases.

# %% [markdown]
# But the enterprise versions might also include features such as identity based access control, quality of service, SSL and SSH inspection for security, and network intrusion prevention as well.

# %% [markdown]
# Now there are always considerations. The principal advantage of a UTM is that it can certainly reduce the complexity. Everything is configured within the one device. But at the same time, this introduces the principal disadvantage of it becoming a single point of failure. If the UTM goes down, all of the services it supplies go down with it. Now, you might still retain some of the other services as backups, or maybe you even have a standby UTM. But it's always something to consider. How will you address the availability of the UTM? But it certainly does reduce the complexity because everything is centralized. And you don't have these different servers, and different applications and different licensing concerns to address each of those threats, hence the term Unified Threat Management.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking9NextgenerationFirewallNGFWLayer7Firewalls"></a>
# ***
# ###### 9. Next-generation Firewall (NGFW) & Layer 7 Firewalls
# ***

# %% [markdown]
# The presenter is Aaron Sampson.] In this presentation, we'll take a look at the next-generation firewall or NGFW. [NGFW.]

# %% [markdown]
# And this is a network security system that can be either hardware or software based. And in fact, the unified threat management that we discussed in the previous presentation is an example of a next-generation firewall.

# %% [markdown]
# It is designed to detect and prevent network attacks through the use of security policies. But they have higher capabilities than traditional firewalls. Because they can consider factors as high as the application layer of the OSI model, whereas traditional firewalls don't really operate at that level. They tend to only work on ports and protocols.

# %% [markdown]
# Now, an NGFW can also be applied down at those levels. But it's able to operate through multiple layers of OSI, so that it provides a more comprehensive security solution.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Next-generation Firewall (NGFW) - Capabilities
# ***

# %% [markdown]
# [NGFW- Capabilities.] So in terms of the capabilities, these are only some examples.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Next-generation Firewall (NGFW) - Capabilities - URL Filtering
# ***

# %% [markdown]
# But you can implement URL filtering, often a suitable replacement for traditional URL filtering proxy devices.

# %% [markdown]
# Earlier we discussed proxy servers and they do have the ability to filter. Well, so can the NGFW. You can categorize websites on the Internet and either allow or block access to them. And the filtering can be enabled during certain times of the day or certain days of the week.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Next-generation Firewall (NGFW) - Capabilities - Application Visibility and Control
# ***

# %% [markdown]
# They can implement application visibility and control. They can detect every application on a network. It provides real-time visibility into the applications being used by the users on a network and can also optimize bandwidth using application aware policy. So that you can allow, deny, or restrict certain applications. You can monitor the application performance and troubleshoot any issues that might arise. And you can improve security and meet compliance requirements for those applications.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Next-generation Firewall (NGFW) - Capabilities - Identity Awareness
# ***

# %% [markdown]
# It also provides identity awareness, policies that are used to enforce requirements for, perhaps, just a single user or any collection of users. And the implementation can be hard coded into firewall rules. They can also inter-operate with an identity repository such as Active Directory, so that they become aware of the users in your environment. Because you can create filtering rules and policies based on the identity of a specific user. So that if this traffic comes from that user, you can implement certain rules.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Next-generation Firewall (NGFW) - Capabilities - IPS Integration
# ***

# %% [markdown]
# IPS integration is the intrusion prevention system which is used to monitor and block malicious network activity. And, of course, this monitors the network traffic for vulnerability exploits, and the key component of an IPS is prevention. You can implement alerts and notifications. You can drop the malicious packets, you can block the source traffic. And of course, reset the connection entirely, if necessary.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Next-generation Firewall (NGFW) - Capabilities - Malware Monitoring
# ***

# %% [markdown]
# And finally, malware monitoring, you can monitor for command and control traffic. You can perform inspection of incoming traffic to try to detect unusual activity. For example, port 80 communication, that is not going to a legitimate website. Port 80 is, of course, HTTP, so you should expect to see port 80 traffic destined for a website, so if it's not, there's something strange about that.

# %% [markdown]
# And you can also block any outgoing communication. So if there's any malware currently active inside an organization, you can at least prevent that information from leaving the organization.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Next-generation Firewall (NGFW) more Comprehensive than traditional Firewall
# ***

# %% [markdown]
# So again, ultimately it is still just a firewall in terms of its ability to protect the internal environment. But at a much more comprehensive level than a traditional firewall.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking10VoIPGateways"></a>
# ***
# ###### 10. VoIP Gateways
# ***

# %% [markdown]
# In this presentation, we'll take a look at VoIP or Voice over Internet Protocol. And two key Components of a VoIP system, the VoIP PBX and the VoIP Gateway.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Voice over Internet Protocol (VoIP)
# ***

# %% [markdown]
# VoIP, of course, enables the use of the Internet to transmit voice calls through the use of various TCP/IP protocols.

# %% [markdown]
# Now, in order to manage those protocols within an organization, you need a VoIP private branch exchange, or PBX. This is the service that functions to direct real-time communication to specific endpoints, such as IP phones. If you've ever seen old time switchboard operators for the phone company, you can think of the VoIP PBX is doing the same job for Voice over IP packets, redirecting references to phone numbers, to specific IP addresses. But what about when a phone number doesn't go to an IP address, but to a traditional telephone endpoint?

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Gateway
# ***

# %% [markdown]
# The VoIP Gateway is the device responsible for converting real-time voice calls and even fax calls between the public switch telephone network, and the IP network of your environment.

# %% [markdown]
# So if for example, you have an IP phone system, you can certainly call each other within the internal environment without having to go through the gateway. But, if you need to make an outside call to the regular phone network, then you need to go through the gateway. And conversely, people from the outside, they're calling in, have to go through the gateway. So it represents the bridge between the two.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### VoIP Gateway - Characteristics
# ***

# %% [markdown]
# In terms of some of its characteristics:

# %% [markdown]
# - It handles voice and fax compression and decompression, so that you're transferring as little data as possible.

# %% [markdown]
# - Packetization, which has to occur in an IP network, you have to transfer packets. Standard analog voice calls don't implement packetization, so you have to convert them into packets.

# %% [markdown]
# - Call routing, if a call comes in from the outside and reaches an automated attendant, for example, they can press one for this department and two for that department, it routes it appropriately.

# %% [markdown]
# - It implements a control signal to ensure that packets are in order and synchronized, so that the conversation doesn't sound garbled.

# %% [markdown]
# - It can handle billing systems, it can track all the calls, so that if you need to implement any kind of invoicing.

# %% [markdown]
# - And various other network management systems might also integrate with the VoIP Gateway.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion
# ***

# %% [markdown]
# So, it can handle the intercommunication between other types of systems that might also be in use. But, ultimately, the VoIP Gateway typically represents that in and out type of system, whereby it bridges the communications between your internal IP network and the public-switched telephone network. So you can use your IP phones both internally and for external access as well.

# %% [markdown]
# This diagram helps us see the big picture. The hardware and software-based IP phones are on the IP network, along with the VoIP PBX which directs the calls. If the call is being made to an endpoint that's outside the company, but a part of a Voice over IP system. Then the packets are directed through the router, out to the VoIP provider, in a way, this is similar to routing external web browser traffic through an ISP's router. For those calls that go to the public-switched telephone network, you can see the VoIP Gateway standing on the threshold with both a phone jack and an Ethernet jack to handle those deliveries.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworking11ContentFilters"></a>
# ***
# ###### 11. Content Filters
# ***

# %% [markdown]
# In this presentation, we'll take a look at implementing content filtering.

# %% [markdown]
# Sometimes referred to as information filtering as well. But this is quite simply the process used to screen and exclude objectionable content on the Internet, particularly web pages, but in many cases in email as well. Now, its typically used in corporations, but can also be implemented in the home environment. For example, using parental controls to perform similar functions to ensure that this objectionable content is not accessable.

# %% [markdown]
# Now, it's implemented through the use of character strings that are specified to see if there is a match. And if a match exists, the undesirable content is screened out. Now, there are a number of examples including filtering violence, medical procedures, adult content, and spoofing and/or phishing content.

# %% [markdown]
# So in many cases, what you'll find is some sort of preset configuration whereby it has thresholds. And you can generally adjust those thresholds to ensure that content that might be legitimate is not screened out, but you can also edit them as well. You can usually say here are some specific examples that should be filtered and/or some specific examples that should not.

# %% [markdown]
# So it gives you sort of a default setting, if you will, which is then very configurable. So that, like I said, you can judge for yourself. Now, it might take a bit of time to get things you know right, for lack of a better word. It might identify some sites as filtered when they shouldn't have been and vice versa. So like I said, there's a bit of a learning curve when it comes to content filtering. But usually the default settings are pretty good, and then you just have to tweak from there. But it is something that you have to keep on top of, to a degree, to ensure that you do get the right balance of allowing what should be allowed while filtering what should be filtered.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practiceAdvancedNetworkingConfiguringAdvancedNetworking"></a>
# ***
# ### Practice: Configuring Advanced Networking
# ***

# %% [markdown]
# i. Recognize when to use a load balancer.
#
#
# ii. Then to describe intrusion detection or prevention systems.
#
#
# iii. Then to describe VPN concentrators.
#
#
# iv. And finally, to list the benefits of using Next Generation Firewalls.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exerciseAdvancedNetworkingConfigureAdvancedNetworkingDevices"></a>
# ***
# ###### 1. Exercise: Configure Advanced Networking Devices
# ***

# %% [markdown]
# i All right, our first task was to recognize when to use a load balancer. And this is implemented when you have multiple servers providing the same service. The load balancer ensures that the distribution of traffic is even across all servers. So that you don't have one that is heavily utilized while another that is very underutilized. A good example is if you have a website, you might implement a server farm or multiple servers to handle the requests for that site. In that case, I want to ensure that all of the servers are responding to the requests in an equal fashion. That is the purpose of the load balancer. It also helps to ensure higher availability because if one server does go down, the request simply will not be sent to that server. So from the user's perspective there's no disruption of service by that downed server.

# %% [markdown]
# ii. Then we asked about intrusion detection and/or prevention systems. And these analyze network traffic patterns to determine what is typical. Then based on that information, they can detect and/or prevent. But detection only refers to logging and alerting the traffic patterns. So it doesn't do anything to stop it. Prevention however, uses that information to decide whether or not it should be allowed. And if it deems that it is not acceptable traffic, it will, in fact, prevent it from happening. So they kind of go hand in hand, but detection in and of itself will not necessarily stop it, prevention will.

# %% [markdown]
# iii. Then we asked about VPN concentrators, this is a device used to centralize all requests for VPN access. And to configure all connection parameters in a centralized location. So that I don't have to go around and configure multiple access points with more or less the same settings. I just direct everyone to go through this single access point and everything can be configured there. I also don't have to dedicate a server to handle the request. I can keep my servers behind the VPN concentrator, so that I'm not exposing one of my servers to the Internet.

# %% [markdown]
# iv. And finally, we asked about the benefits of using Next Generation Firewalls. This allows you to address the many types of network vulnerabilities in a single device or application, including anti-virus or anti-spam and malware monitoring. Intrusion detection and/ or intrusion prevention systems. Identity awareness and content filtering, among others.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="advancedNetworkingTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# # END JUPYTER NOTEBOOK
